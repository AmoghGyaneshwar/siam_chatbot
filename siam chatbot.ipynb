# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Amog\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Amog\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 31 documents
# 6 classes ['about', 'ccs', 'goodbye', 'greeting', 'options', 'thanks']
# 55 unique lemmatized words ["'s", ',', 'anyone', 'apply', 'are', 'awesome', 'be', 'bye', 'can', 'cc', 'chatting', 'could', 'day', 'do', 'doe', 'expect', 'for', 'from', 'get', 'good', 'goodbye', 'happens', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'hola', 'how', 'i', 'in', 'into', 'is', 'later', 'me', 'next', 'nice', 'offered', 'procedure', 'provide', 'see', 'siam', 'stand', 'support', 'thank', 'thanks', 'that', 'the', 'there', 'till', 'time', 'to', 'what', 'you']

# %%
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# 31/31 [==============================] - 0s 12ms/step - loss: 1.8833 - accuracy: 0.0968
# Epoch 2/200
# 31/31 [==============================] - 0s 869us/step - loss: 1.8144 - accuracy: 0.1613
# Epoch 3/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.7821 - accuracy: 0.2258
# Epoch 4/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.6605 - accuracy: 0.2581
# Epoch 5/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6209 - accuracy: 0.4194
# Epoch 6/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5682 - accuracy: 0.4194
# Epoch 7/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5850 - accuracy: 0.5161
# Epoch 8/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5130 - accuracy: 0.4516
# Epoch 9/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.4133 - accuracy: 0.4516
# Epoch 10/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.4394 - accuracy: 0.3871
# Epoch 11/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.1926 - accuracy: 0.6129
# Epoch 12/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.1696 - accuracy: 0.8065
# Epoch 13/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1258 - accuracy: 0.6129
# Epoch 14/200
# 31/31 [==============================] - ETA: 0s - loss: 1.8454 - accuracy: 0.20 - 0s 2ms/step - loss: 1.0397 - accuracy: 0.6129
# Epoch 15/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8400 - accuracy: 0.8387
# Epoch 16/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8953 - accuracy: 0.6774
# Epoch 17/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6390 - accuracy: 0.9677
# Epoch 18/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8136 - accuracy: 0.6774
# Epoch 19/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7597 - accuracy: 0.8065
# Epoch 20/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6379 - accuracy: 0.8065
# Epoch 21/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6463 - accuracy: 0.8387
# Epoch 22/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5681 - accuracy: 0.8387
# Epoch 23/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6069 - accuracy: 0.7742
# Epoch 24/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3928 - accuracy: 0.9032
# Epoch 25/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4764 - accuracy: 0.8387
# Epoch 26/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5650 - accuracy: 0.6774
# Epoch 27/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4153 - accuracy: 0.8710: 0s - loss: 0.4412 - accuracy: 0.85
# Epoch 28/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3507 - accuracy: 0.9355
# Epoch 29/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2086 - accuracy: 1.0000
# Epoch 30/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2569 - accuracy: 0.9355
# Epoch 31/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2398 - accuracy: 0.9032
# Epoch 32/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3795 - accuracy: 0.8065
# Epoch 33/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2226 - accuracy: 0.9677
# Epoch 34/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2039 - accuracy: 0.9355
# Epoch 35/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2128 - accuracy: 0.9355
# Epoch 36/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2070 - accuracy: 0.9355
# Epoch 37/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2281 - accuracy: 0.9032
# Epoch 38/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1514 - accuracy: 0.9355
# Epoch 39/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2141 - accuracy: 0.9677
# Epoch 40/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2454 - accuracy: 0.9032
# Epoch 41/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1365 - accuracy: 0.9677: 0s - loss: 0.1410 - accuracy: 0.96
# Epoch 42/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1206 - accuracy: 0.9677: 0s - loss: 0.1246 - accuracy: 0.96
# Epoch 43/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2764 - accuracy: 0.9355
# Epoch 44/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1629 - accuracy: 1.0000
# Epoch 45/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1107 - accuracy: 1.0000
# Epoch 46/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1068 - accuracy: 1.0000
# Epoch 47/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1663 - accuracy: 1.0000
# Epoch 48/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1460 - accuracy: 0.9677
# Epoch 49/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1091 - accuracy: 0.9677
# Epoch 50/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1165 - accuracy: 0.9677
# Epoch 51/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1549 - accuracy: 0.9677
# Epoch 52/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1806 - accuracy: 0.9355
# Epoch 53/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0853 - accuracy: 1.0000
# Epoch 54/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1856 - accuracy: 0.9677
# Epoch 55/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0573 - accuracy: 1.0000
# Epoch 56/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0921 - accuracy: 1.0000
# Epoch 57/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0914 - accuracy: 1.0000
# Epoch 58/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0577 - accuracy: 1.0000
# Epoch 59/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 60/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0754 - accuracy: 1.0000
# Epoch 61/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1770 - accuracy: 0.9355
# Epoch 62/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 63/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0994 - accuracy: 1.0000
# Epoch 64/200
# 31/31 [==============================] - 0s 901us/step - loss: 0.0608 - accuracy: 1.0000
# Epoch 65/200
# 31/31 [==============================] - 0s 644us/step - loss: 0.1149 - accuracy: 0.9677
# Epoch 66/200
# 31/31 [==============================] - 0s 836us/step - loss: 0.1474 - accuracy: 0.9677
# Epoch 67/200
# 31/31 [==============================] - 0s 611us/step - loss: 0.0827 - accuracy: 1.0000
# Epoch 68/200
# 31/31 [==============================] - 0s 547us/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 69/200
# 31/31 [==============================] - 0s 770us/step - loss: 0.0667 - accuracy: 1.0000
# Epoch 70/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0632 - accuracy: 0.9677
# Epoch 71/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1149 - accuracy: 0.9355
# Epoch 72/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 73/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 74/200
# 31/31 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0627 - accuracy: 0.9677
# Epoch 75/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0844 - accuracy: 0.9677
# Epoch 76/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1193 - accuracy: 0.9355
# Epoch 77/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 78/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0758 - accuracy: 0.9677
# Epoch 79/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1194 - accuracy: 0.9677
# Epoch 80/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 81/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 82/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0724 - accuracy: 0.9677
# Epoch 83/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 84/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 85/200
# 31/31 [==============================] - 0s 965us/step - loss: 0.0702 - accuracy: 0.9677
# Epoch 86/200
# 31/31 [==============================] - 0s 804us/step - loss: 0.0970 - accuracy: 0.9677
# Epoch 87/200
# 31/31 [==============================] - 0s 643us/step - loss: 0.0580 - accuracy: 0.9677
# Epoch 88/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 89/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 90/200
# 31/31 [==============================] - 0s 772us/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 91/200
# 31/31 [==============================] - 0s 643us/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 92/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 93/200
# 31/31 [==============================] - 0s 708us/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 94/200
# 31/31 [==============================] - 0s 804us/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 95/200
# 31/31 [==============================] - 0s 611us/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 96/200
# 31/31 [==============================] - 0s 797us/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 97/200
# 31/31 [==============================] - 0s 836us/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 98/200
# 31/31 [==============================] - 0s 643us/step - loss: 0.1644 - accuracy: 0.9677
# Epoch 99/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 100/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 101/200
# 31/31 [==============================] - 0s 836us/step - loss: 0.0273 - accuracy: 1.0000
# Epoch 102/200
# 31/31 [==============================] - 0s 707us/step - loss: 0.0566 - accuracy: 1.0000
# Epoch 103/200
# 31/31 [==============================] - 0s 772us/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 104/200
# 31/31 [==============================] - 0s 869us/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 105/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 106/200
# 31/31 [==============================] - 0s 611us/step - loss: 0.0714 - accuracy: 0.9355
# Epoch 107/200
# 31/31 [==============================] - 0s 642us/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 108/200
# 31/31 [==============================] - 0s 643us/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 109/200
# 31/31 [==============================] - 0s 965us/step - loss: 0.0439 - accuracy: 1.0000
# Epoch 110/200
# 31/31 [==============================] - 0s 772us/step - loss: 0.0376 - accuracy: 0.9677
# Epoch 111/200
# 31/31 [==============================] - 0s 611us/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 112/200
# 31/31 [==============================] - 0s 708us/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 113/200
# 31/31 [==============================] - 0s 579us/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 114/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0730 - accuracy: 0.9677
# Epoch 115/200
# 31/31 [==============================] - 0s 740us/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 116/200
# 31/31 [==============================] - 0s 676us/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 117/200
# 31/31 [==============================] - 0s 579us/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 118/200
# 31/31 [==============================] - 0s 708us/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 119/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 120/200
# 31/31 [==============================] - 0s 708us/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 121/200
# 31/31 [==============================] - 0s 740us/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 122/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 123/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 124/200
# 31/31 [==============================] - 0s 868us/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 125/200
# 31/31 [==============================] - 0s 676us/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 126/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 127/200
# 31/31 [==============================] - 0s 804us/step - loss: 0.0566 - accuracy: 1.0000
# Epoch 128/200
# 31/31 [==============================] - 0s 740us/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 129/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 130/200
# 31/31 [==============================] - 0s 997us/step - loss: 0.0580 - accuracy: 0.9677
# Epoch 131/200
# 31/31 [==============================] - 0s 579us/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 132/200
# 31/31 [==============================] - 0s 547us/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 133/200
# 31/31 [==============================] - 0s 983us/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 134/200
# 31/31 [==============================] - 0s 997us/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 135/200
# 31/31 [==============================] - 0s 772us/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 136/200
# 31/31 [==============================] - 0s 751us/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 137/200
# 31/31 [==============================] - 0s 966us/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 138/200
# 31/31 [==============================] - 0s 836us/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 139/200
# 31/31 [==============================] - 0s 579us/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 140/200
# 31/31 [==============================] - 0s 708us/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 141/200
# 31/31 [==============================] - 0s 579us/step - loss: 0.0873 - accuracy: 0.9677
# Epoch 142/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 143/200
# 31/31 [==============================] - 0s 838us/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 144/200
# 31/31 [==============================] - 0s 804us/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 145/200
# 31/31 [==============================] - 0s 579us/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 146/200
# 31/31 [==============================] - 0s 933us/step - loss: 0.0704 - accuracy: 0.9355
# Epoch 147/200
# 31/31 [==============================] - 0s 740us/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 148/200
# 31/31 [==============================] - 0s 579us/step - loss: 0.0498 - accuracy: 1.0000
# Epoch 149/200
# 31/31 [==============================] - 0s 547us/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 150/200
# 31/31 [==============================] - 0s 592us/step - loss: 0.0767 - accuracy: 0.9677
# Epoch 151/200
# 31/31 [==============================] - 0s 772us/step - loss: 0.0337 - accuracy: 1.0000
# Epoch 152/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 153/200
# 31/31 [==============================] - 0s 596us/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 154/200
# 31/31 [==============================] - 0s 611us/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 155/200
# 31/31 [==============================] - 0s 579us/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 156/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0610 - accuracy: 0.9677
# Epoch 157/200
# 31/31 [==============================] - 0s 579us/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 158/200
# 31/31 [==============================] - 0s 804us/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 159/200
# 31/31 [==============================] - 0s 644us/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 160/200
# 31/31 [==============================] - 0s 804us/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 161/200
# 31/31 [==============================] - 0s 836us/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 162/200
# 31/31 [==============================] - 0s 611us/step - loss: 0.0592 - accuracy: 0.9677
# Epoch 163/200
# 31/31 [==============================] - 0s 579us/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 164/200
# 31/31 [==============================] - 0s 579us/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 165/200
# 31/31 [==============================] - 0s 900us/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 166/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 167/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 168/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 169/200
# 31/31 [==============================] - 0s 869us/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 170/200
# 31/31 [==============================] - 0s 643us/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 171/200
# 31/31 [==============================] - 0s 740us/step - loss: 0.0722 - accuracy: 0.9677
# Epoch 172/200
# 31/31 [==============================] - 0s 805us/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 173/200
# 31/31 [==============================] - 0s 900us/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 174/200
# 31/31 [==============================] - 0s 740us/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 175/200
# 31/31 [==============================] - 0s 740us/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 176/200
# 31/31 [==============================] - 0s 772us/step - loss: 0.0278 - accuracy: 1.0000
# Epoch 177/200
# 31/31 [==============================] - 0s 901us/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 178/200
# 31/31 [==============================] - 0s 804us/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 179/200
# 31/31 [==============================] - 0s 611us/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 180/200
# 31/31 [==============================] - 0s 676us/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 181/200
# 31/31 [==============================] - 0s 579us/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 182/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 183/200
# 31/31 [==============================] - 0s 708us/step - loss: 0.0294 - accuracy: 1.0000
# Epoch 184/200
# 31/31 [==============================] - 0s 547us/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 185/200
# 31/31 [==============================] - 0s 579us/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 186/200
# 31/31 [==============================] - 0s 610us/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 187/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 188/200
# 31/31 [==============================] - 0s 965us/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 189/200
# 31/31 [==============================] - 0s 772us/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 190/200
# 31/31 [==============================] - 0s 772us/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 191/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 192/200
# 31/31 [==============================] - 0s 836us/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 193/200
# 31/31 [==============================] - 0s 708us/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 194/200
# 31/31 [==============================] - 0s 708us/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 195/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 196/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 197/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 198/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 199/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 200/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 0.9677
# model created

# %%
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)


base = Tk()
base.title("SIAM CHATBOT")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
